# %%
import pandas as pd
man = pd.read_excel('/content/경륜 DB.xlsx', sheet_name='현역선수명단')

# %%
man = man.drop(columns='기타사항')
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   선수번호    541 non-null    int64
#  1   이름      541 non-null    object
#  2   아마경력    540 non-null    object
#  3   혈액형     539 non-null    object
#  4   가슴둘레    541 non-null    float64
#  5   출신지     501 non-null    object
#  6   출신팀     420 non-null    object
#  7   시력(좌)   541 non-null    float64
#  8   시력(우)   541 non-null    float64
#  9   대퇴(위좌)  537 non-null    float64
#  10  대퇴(위우)  537 non-null    float64
#  11  하퇴(위좌)  541 non-null    float64
#  12  하퇴(위우)  541 non-null    float64
#  13  기수      541 non-null    int64
#  14  결혼      479 non-null    object
#  15  고등학교    540 non-null    object
#  16  흡연유무    540 non-null    object
#  17  신장      541 non-null    float64
#  18  출신팀.1   361 non-null    object
#  19  체중      541 non-null    float64
#  20  출생년도    541 non-null    object
# ...
